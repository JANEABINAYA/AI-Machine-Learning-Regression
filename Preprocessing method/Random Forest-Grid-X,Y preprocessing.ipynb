# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/
3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'criterion': ['squared_error', 'absolute_error']  
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'criterion': ['squared_error', 'absolute_error']
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Felex\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 10, 20],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.
best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_depth': 10, 'n_estimators': 200}: 0.8732077461939481

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.447948      0.020939         0.018610        0.002613
# 1        1.136332      0.258480         0.051186        0.013074
# 2        0.623541      0.197834         0.029037        0.004862
# 3        1.785346      0.056425         0.050246        0.004591
# 4        1.018592      0.055127         0.037177        0.012747
# 5        2.135445      0.030148         0.062251        0.010638
# 6        3.409466      0.139679         0.031431        0.009106
# 7        6.307018      0.147868         0.051271        0.006075
# 8        3.016584      0.123860         0.025383        0.002013
# 9        5.522691      0.022460         0.046366        0.005947
# 10       2.900528      0.030048         0.025698        0.005216
# 11       4.816538      0.118512         0.035809        0.007073
#
#    param_criterion param_max_depth  param_n_estimators  \
# 0    squared_error            None                 100
# 1    squared_error            None                 200
# 2    squared_error              10                 100
# 3    squared_error              10                 200
# 4    squared_error              20                 100
# 5    squared_error              20                 200
# 6   absolute_error            None                 100
# 7   absolute_error            None                 200
# 8   absolute_error              10                 100
# 9   absolute_error              10                 200
# 10  absolute_error              20                 100
# 11  absolute_error              20                 200
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.806030
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.803982
# 2   {'criterion': 'squared_error', 'max_depth': 10...           0.800034
# 3   {'criterion': 'squared_error', 'max_depth': 10...           0.799213
# 4   {'criterion': 'squared_error', 'max_depth': 20...           0.809641
# 5   {'criterion': 'squared_error', 'max_depth': 20...           0.804250
# 6   {'criterion': 'absolute_error', 'max_depth': N...           0.785543
# 7   {'criterion': 'absolute_error', 'max_depth': N...           0.781461
# 8   {'criterion': 'absolute_error', 'max_depth': 1...           0.803926
# 9   {'criterion': 'absolute_error', 'max_depth': 1...           0.804700
# 10  {'criterion': 'absolute_error', 'max_depth': 2...           0.786690
# 11  {'criterion': 'absolute_error', 'max_depth': 2...           0.785378
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.758666           0.839897           0.800701
# 1            0.751240           0.835201           0.808531
# 2            0.743177           0.836606           0.811017
# 3            0.761563           0.840901           0.810745
# 4            0.748477           0.835466           0.801033
# 5            0.751871           0.835400           0.810877
# 6            0.772712           0.821721           0.803503
# 7            0.766115           0.816688           0.802303
# 8            0.790218           0.829828           0.813682
# 9            0.784015           0.835070           0.823191
# 10           0.771163           0.819414           0.806671
# 11           0.771198           0.814199           0.808504
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.765621         0.794183        0.029495                4
# 1            0.764568         0.792704        0.030642                6
# 2            0.768383         0.791843        0.032733                7
# 3            0.767263         0.795937        0.029174                3
# 4            0.760027         0.790929        0.032227                8
# 5            0.764523         0.793384        0.030808                5
# 6            0.759705         0.788637        0.021981                9
# 7            0.760720         0.785457        0.021265               12
# 8            0.770220         0.801575        0.020310                2
# 9            0.770626         0.803520        0.023859                1
# 10           0.755453         0.787878        0.023151               10
# 11           0.756695         0.787195        0.021784               11

# %%
import pickle
filename = 'finalized_model_Random forest.sav'

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
preinput=sc.transform([[19, 27.900, 0, 0, 1]])
# Out:
# C:\Users\Felex\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46814257, -0.44801942, -0.90788827, -0.98885138,  2.00280702]])

# %%
with open('finalized_model_Random forest.sav', 'rb') as file:
    loaded_model = pickle.load(file)
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([17101.53735218])
