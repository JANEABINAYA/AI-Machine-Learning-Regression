# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/
3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'criterion': ['squared_error', 'absolute_error']  
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'criterion': ['squared_error', 'absolute_error']
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Felex\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 10, 20],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.
best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_depth': 10, 'n_estimators': 200}: 0.872962134528984

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.909093      0.103013         0.030782        0.001928
# 1        2.194233      0.195980         0.067686        0.011131
# 2        1.107809      0.064112         0.030509        0.005523
# 3        1.400495      0.159372         0.024757        0.004617
# 4        0.521374      0.070172         0.016895        0.002117
# 5        0.912432      0.053519         0.031511        0.010957
# 6        1.733292      0.270953         0.029862        0.016140
# 7        4.951603      0.035505         0.030653        0.013017
# 8        2.336764      0.557265         0.018951        0.011770
# 9        4.512530      0.056481         0.027434        0.011170
# 10       2.450405      0.637111         0.031100        0.013019
# 11       4.373900      0.039492         0.017463        0.007498
#
#    param_criterion param_max_depth  param_n_estimators  \
# 0    squared_error            None                 100
# 1    squared_error            None                 200
# 2    squared_error              10                 100
# 3    squared_error              10                 200
# 4    squared_error              20                 100
# 5    squared_error              20                 200
# 6   absolute_error            None                 100
# 7   absolute_error            None                 200
# 8   absolute_error              10                 100
# 9   absolute_error              10                 200
# 10  absolute_error              20                 100
# 11  absolute_error              20                 200
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.801869
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.798891
# 2   {'criterion': 'squared_error', 'max_depth': 10...           0.805336
# 3   {'criterion': 'squared_error', 'max_depth': 10...           0.809176
# 4   {'criterion': 'squared_error', 'max_depth': 20...           0.799647
# 5   {'criterion': 'squared_error', 'max_depth': 20...           0.803783
# 6   {'criterion': 'absolute_error', 'max_depth': N...           0.784043
# 7   {'criterion': 'absolute_error', 'max_depth': N...           0.779487
# 8   {'criterion': 'absolute_error', 'max_depth': 1...           0.796882
# 9   {'criterion': 'absolute_error', 'max_depth': 1...           0.807567
# 10  {'criterion': 'absolute_error', 'max_depth': 2...           0.786575
# 11  {'criterion': 'absolute_error', 'max_depth': 2...           0.784193
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.754178           0.834460           0.807931
# 1            0.755742           0.836069           0.806781
# 2            0.757239           0.839596           0.809298
# 3            0.754374           0.841527           0.806565
# 4            0.754922           0.832564           0.798996
# 5            0.753830           0.832173           0.808231
# 6            0.760506           0.817059           0.798291
# 7            0.766960           0.819206           0.805806
# 8            0.782279           0.824707           0.814720
# 9            0.784355           0.826905           0.819678
# 10           0.769131           0.821963           0.804328
# 11           0.769428           0.821160           0.807266
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.761364         0.791960        0.030077                7
# 1            0.764317         0.792360        0.029286                6
# 2            0.770207         0.796335        0.029434                3
# 3            0.766946         0.795717        0.031415                4
# 4            0.764909         0.790208        0.027733                8
# 5            0.763889         0.792381        0.029198                5
# 6            0.759796         0.783939        0.022068               12
# 7            0.758821         0.786056        0.022972               11
# 8            0.772170         0.798152        0.019536                2
# 9            0.769739         0.801649        0.021519                1
# 10           0.754936         0.787387        0.023956               10
# 11           0.762662         0.788942        0.022216                9

# %%
import pickle
filename = 'finalized_model_Random forest.sav'
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model = pickle.load(open('finalized_model_SVR.sav', 'rb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 4
# BMI: 56
# Children: 5
# Sex Male 0 or 1: 5
# Smoker Yes 0 or 1: 3

# %%
Future_Prediction=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[57418.49065245]
