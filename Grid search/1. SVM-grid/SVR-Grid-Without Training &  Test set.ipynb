# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn import svm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {
    'kernel': ['linear', 'rbf'],  # SVR uses different hyperparameters than RandomForest
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Felex\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
print("The R_score value for best parameter {}:", grid.best_params_)
# Out:
# The R_score value for best parameter {}: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}

# %%
table = pd.DataFrame.from_dict(grid.cv_results_)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.108368      0.004797         0.020392        0.004856      0.1
# 1        0.196926      0.053180         0.137288        0.008720      0.1
# 2        0.209833      0.002617         0.039125        0.005784      0.1
# 3        0.286969      0.005673         0.158495        0.011673      0.1
# 4        0.261758      0.032211         0.044304        0.004751      1.0
# 5        0.306489      0.012986         0.146503        0.006261      1.0
# 6        0.236877      0.005718         0.037376        0.004047      1.0
# 7        0.276533      0.007560         0.136938        0.008283      1.0
# 8        0.272744      0.023425         0.035591        0.003652     10.0
# 9        0.248158      0.011111         0.135358        0.003914     10.0
# 10       0.262573      0.013274         0.029025        0.010118     10.0
# 11       0.192085      0.047095         0.046299        0.006136     10.0
#
#    param_gamma param_kernel                                            params  \
# 0        scale       linear  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 1        scale          rbf     {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 2         auto       linear   {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 3         auto          rbf      {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 4        scale       linear    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 5        scale          rbf       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 6         auto       linear     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 7         auto          rbf        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 8        scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 9        scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 10        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 11        auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.156586          -0.102518          -0.117799
# 1           -0.115326          -0.113152          -0.081428
# 2           -0.156586          -0.102518          -0.117799
# 3           -0.115312          -0.113526          -0.081580
# 4           -0.147592          -0.090685          -0.104805
# 5           -0.115390          -0.110235          -0.079858
# 6           -0.147592          -0.090685          -0.104805
# 7           -0.115171          -0.113204          -0.081329
# 8           -0.018943           0.029886           0.022167
# 9           -0.110409          -0.097459          -0.074488
# 10          -0.018943           0.029886           0.022167
# 11          -0.113791          -0.110741          -0.079156
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.140213          -0.216269        -0.146677        0.039413
# 1           -0.105862          -0.107303        -0.104614        0.012116
# 2           -0.140213          -0.216269        -0.146677        0.039413
# 3           -0.106043          -0.107188        -0.104730        0.012108
# 4           -0.123874          -0.202393        -0.133870        0.039226
# 5           -0.104068          -0.108358        -0.103582        0.012406
# 6           -0.123874          -0.202393        -0.133870        0.039226
# 7           -0.105826          -0.107122        -0.104530        0.012126
# 8            0.003112          -0.066653        -0.006086        0.034672
# 9           -0.099597          -0.124428        -0.101276        0.016459
# 10           0.003112          -0.066653        -0.006086        0.034672
# 11          -0.103389          -0.106488        -0.102713        0.012303
#
#     rank_test_score
# 0                11
# 1                 7
# 2                11
# 3                 8
# 4                 9
# 5                 5
# 6                 9
# 7                 6
# 8                 1
# 9                 3
# 10                1
# 11                4

# %%
import pickle
filename = 'finalized_model_SVR.sav'
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model = pickle.load(open('finalized_model_SVR.sav', 'rb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 4
# BMI: 56
# Children: 5
# Sex Male 0 or 1: 5
# Smoker Yes 0 or 1: 3

# %%
Future_Prediction=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[6573.94776961]
# C:\Users\Felex\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
